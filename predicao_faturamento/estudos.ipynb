# %% [markdown]
# # Estudos predição faturamento

# %%
import pandas as pd
from pathlib import Path

dataset = Path.joinpath(Path('__file__').parent, 'dataset', 'df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Documents\cursos\udemy\python_sist_desk_mysql\projetos\predicao_faturamento\estudos.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/d%3A/Documents/cursos/udemy/python_sist_desk_mysql/projetos/predicao_faturamento/estudos.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/Documents/cursos/udemy/python_sist_desk_mysql/projetos/predicao_faturamento/estudos.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from pathlib import Path
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/cursos/udemy/python_sist_desk_mysql/projetos/predicao_faturamento/estudos.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> dataset = Path.joinpath(Path(__file__).parent, 'dataset', 'df.csv')
#
# NameError: name '__file__' is not defined

# %% [markdown]
# ## Carregamento dos dados

# %%
df = pd.read_csv(dataset).round(2)

df.head()
